# %%
from boox_app.factories import BookFactory
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_15026/11110266.py in <module>
# ----> 1 from boox_app.factories import BookFactory
#
# ~/code/Boox/boox_app/factories.py in <module>
#       5
#       6 @factory.django.mute_signals(post_save)
# ----> 7 class UserFactory(factory.django.DjangoModelFactory):
#       8     class Meta:
#       9         model = "boox_app.User"
#
# ~/code/Boox/boox_app/factories.py in UserFactory()
#      13     name = factory.Sequence(lambda n: f"user_{n}")
#      14     email = factory.Sequence(lambda n: f"user_{n}@mail.com")
# ---> 15     password = (make_password("p"),)
#      16
#      17
#
# ~/PycharmProjects/dzt-api/venv/lib/python3.7/site-packages/django/contrib/auth/hashers.py in make_password(password, salt, hasher)
#      73     if password is None:
# ...
